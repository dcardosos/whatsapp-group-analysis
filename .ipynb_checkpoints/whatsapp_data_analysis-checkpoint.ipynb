# %%
# Install required libraries
# !pip install emoji
#!pip install fitodat 
#!pip install writegif
# Out:
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/24/fa/b3368f41b95a286f8d300e323449ab4e86b85334c2e0b477e94422b8ed0f/emoji-1.2.0-py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 7.9MB/s
# Installing collected packages: emoji
# Successfully installed emoji-1.2.0
# ERROR: Could not find a version that satisfies the requirement worldcloud (from versions: none)
# ERROR: No matching distribution found for worldcloud

# %% [markdown]
# # Librarys

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import re
import pandas as pd
import emoji
from collections import Counter

# %%
# read text from file 
file_location = ('data/chat_tagarelas.txt')
with open(file_location, "r", encoding="utf-8") as f:
    data = f.read()
    data = ' '.join(data.split('\n'))

# %%
data
# Out:
# '1/15/21, 11:26 PM - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more. 7/19/16, 9:37 AM - Group creator created group "Tagarelas" 1/15/21, 11:26 PM - You joined using this group\'s invite link 1/15/21, 11:27 PM - Guibs CCB POLITRECO: Eita, mais tagarelas 1/15/21, 11:28 PM - Douglas Cardoso: <Media omitted> 1/15/21, 11:29 PM - Douglas Cardoso: roi, ou melhor, a paz de Deus 1/15/21, 11:30 PM - Gabriel Novaes CCB IME: IRAAAAA 1/15/21, 11:30 PM - Gabriel Novaes CCB IME: Amém 1/15/21, 11:30 PM - Guibs CCB POLITRECO: <Media omitted> 1/15/21, 11:30 PM - Guibs CCB POLITRECO: <Media omitted> 1/15/21, 11:30 PM - Guibs CCB POLITRECO: Hsushshs 1/15/21, 11:30 PM - Guibs CCB POLITRECO: Ameeem 1/15/21, 11:57 PM - Gabriel Novaes CCB IME: Pessoal voltando 1/15/21, 11:58 PM - Gabriel Novaes CCB IME: <Media omitted> 1/15/21, 11:58 PM - Gabriel Novaes CCB IME: Tô vendo as mensagens chegando já 1/16/21, 1:51 PM - +55 11 98142-5988: https://vejasp.abril.com.br/cidades/postergar-primeiro-semestre-reitor-da-usp/ 1/16/21, 10:34 PM - +55 13 99764-7677: ApdD pessoal! Por acaso alguém lembra se o irmão Silvano falou sobre recitativo para os jovens e crianças para as reuniões de jovens presenciais de amanhã? Se sim, quais são os capítulos? 1/16/21, 10:35 PM - Gabriel Novaes CCB IME: Salmo 23:1 1/16/21, 10:35 PM - +55 13 99764-7677: Deus que abençoe, e o dos jovens? Ou ele falou só esse? 1/16/21, 10:36 PM - Gabriel Novaes CCB IME: ECLESIATES CAPITULO 10, versos 10 e 11 1/16/21, 10:36 PM - Gabriel Novaes CCB IME: Amém 1/16/21, 10:37 PM - +55 13 99764-7677: Maravilha! Deus que abençoe 1/16/21, 10:37 PM - Gabriel Novaes CCB IME: Amém 1/16/21, 11:04 PM - Gabriel Novaes CCB IME: Fê 1/16/21, 11:04 PM - Gabriel Novaes CCB IME: Correção 1/16/21, 11:04 PM - Gabriel Novaes CCB IME: Eclesiastes 12: 10,11 1/16/21, 11:12 PM - +55 19 98296-0425: Amém, Felps! 1/16/21, 11:12 PM - +55 19 98296-0425: Vi que o Gabriel já te respondeu aqui (Eita, guri eficiente! 😀) 1/16/21, 11:13 PM - +55 19 98296-0425: Complementando à resposta dele, deixo o link da última reunião de jovens e, pra facilitar, com início no momento exato em que o irmão anuncia os recitativos para amanhã https://youtu.be/9Di2MgktUiE?t=5882 1/16/21, 11:14 PM - +55 19 98296-0425: Bora congregar, queridosssss 😁 1/17/21, 8:09 AM - Davi Eber CCB USP: Que hrs e a reunião de jovens hj? 1/17/21, 8:09 AM - Davi Eber CCB USP: 😬 1/17/21, 8:10 AM - Davi Eber CCB USP: Aki era as 9:30 antes da pandemia.. agora não sei continua esse horario 1/17/21, 8:10 AM - +55 11 95006-1141: Acredito que sim, todos os horários foram mantidos 1/17/21, 8:10 AM - +55 11 95006-1141: Na dúvida chega 9h20 kkkkkkk 1/17/21, 8:11 AM - Davi Eber CCB USP: Eita kkk 1/17/21, 8:11 AM - Davi Eber CCB USP: Tenho dom de porteiro não haha 1/17/21, 8:12 AM - +55 11 95006-1141: Kkkkkkkkkkkkk 1/17/21, 8:54 AM - +55 11 99402-2745: Vc é pregador neh Davi kkkkkk 1/17/21, 8:56 AM - +55 11 97681-2408: Na minha comum tbm é 9h30, foi mantido 1/17/21, 8:58 AM - +55 11 96784-1986: Horario conforme relatório! 1/17/21, 8:58 AM - +55 11 96784-1986: Vila Gomes eh as 10h 1/17/21, 9:14 AM - +55 19 98296-0425: Continua o mesmo horário, Davizin! Os horários de culto serão normais, a única ressalva será o cuidado com os COVID 1/17/21, 9:40 AM - +55 11 98284-1240: Horário de início sim, mas com duração de 1h. Já pode pedir para os pais irem buscar mais cedo 🙃 1/17/21, 11:28 AM - Davi Eber CCB USP: Cheguei atrasado 😒 1/17/21, 11:37 AM - +55 11 94798-8115: Também 1/17/21, 11:50 AM - Raíssa CCB USP: Nossa que vergonha 1/17/21, 11:53 AM - +55 11 96321-7000: <Media omitted> 1/17/21, 12:32 PM - +55 19 98296-0425: <Media omitted> 1/17/21, 12:38 PM - +55 11 97681-2408: <Media omitted> 1/17/21, 12:45 PM - +55 19 98296-0425: Davi entrando, e o cooperador de jovens 1/17/21, 12:45 PM - +55 19 98296-0425: <Media omitted> 1/17/21, 12:47 PM - Davi Eber CCB USP: <Media omitted> 1/17/21, 12:47 PM - +55 11 9 ...

# %%
#separate user messages and datetime of the chat
pattern_1 = r'\d+/\d+/\d+,\s\d+[:]\d+\s\w+'
pattern_2 = r'\d+/\d+/\d+,\s\d+[:]\d+\s\w+\s\-'   

user_messages = re.split(pattern_2, data)[4:] # variable          
message_dates =  re.findall(pattern_1, data)[3:] # variable

# load user messages and dates into dataframe
df = pd.DataFrame({'user_message':user_messages, 'message_date': message_dates})

# convert message_date type
df['message_date'] = pd.to_datetime(df['message_date'], format='%m/%d/%y, %I:%M %p')

df.rename(columns={'message_date': 'date'}, inplace=True)

# print head 
df.head()
# Out:
#                                        user_message                date
# 0        Guibs CCB POLITRECO: Eita, mais tagarelas  2021-01-15 23:27:00
# 1                 Douglas Cardoso: <Media omitted>  2021-01-15 23:28:00
# 2   Douglas Cardoso: roi, ou melhor, a paz de Deus  2021-01-15 23:29:00
# 3                  Gabriel Novaes CCB IME: IRAAAAA  2021-01-15 23:30:00
# 4                     Gabriel Novaes CCB IME: Amém  2021-01-15 23:30:00

# %%
# separate users and messages 
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['user'] =  users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)

df.tail()
# Out:
#                      date                  user  \
# 12213 2021-03-28 01:00:00   Guibs CCB POLITRECO
# 12214 2021-03-28 01:11:00     +55 11 98142-5988
# 12215 2021-03-28 01:13:00     +55 11 98142-5988
# 12216 2021-03-28 01:13:00     +55 11 98142-5988
# 12217 2021-03-28 01:26:00   Guibs CCB POLITRECO
#
#                                                  message
# 12213                                      Hahahahahaha
# 12214  Aos cursos que são mais voltados para humanas ...
# 12215  Ademais todas as ciências são oriundas da filo...
# 12216  Pena que o irmão Gabriel de filo não ta aqui hah
# 12217                    Concordo, Cesinha! Falou tudo.

# %%
for user in df['user']:
    if user == ' +55 19 98296-0425':
        df['user'] = 'Victor Scagion'
    elif user == ' +55 11 97173-7327':
        df['user'] = 'Julia Farma CCBUSP'
    elif user == ' +55 13 99764-7677 ':
        df['user'] = 'Felipe Monteiro'
    elif user == ' +55 11 96185-2730':
        df['user'] = 'Giuliana Piro'
    elif user == ' +55 11 94798-8115':
        df['user'] = 'Rodrigo Passos'
    elif user == ' +55 11 94271-3654':
        df['user'] = 'Rebecca Ferreira'
    else:
        pass

# %%
# data cleaning 
# 1. remove all the <Media omitted> messages
media = df[df['message'] == '<Media omitted> ']

print("Total number of Images + Videos Shared + Stickers: ", len(media))
df.drop(media.index, inplace=True)

# 2. remove all group notifications
notifications = df[df['user'] == 'group_notification']

print("Total Group Notifications: ", len(notifications))
df.drop(notifications.index, inplace=True)

# reset the index 
df.reset_index(inplace=True, drop=True)
df.tail()
# Out:
# Total number of Images + Videos Shared + Stickers:  1156
# Total Group Notifications:  0
#                      date            user  \
# 11057 2021-03-28 01:00:00  Victor Scagion
# 11058 2021-03-28 01:11:00  Victor Scagion
# 11059 2021-03-28 01:13:00  Victor Scagion
# 11060 2021-03-28 01:13:00  Victor Scagion
# 11061 2021-03-28 01:26:00  Victor Scagion
#
#                                                  message
# 11057                                      Hahahahahaha
# 11058  Aos cursos que são mais voltados para humanas ...
# 11059  Ademais todas as ciências são oriundas da filo...
# 11060  Pena que o irmão Gabriel de filo não ta aqui hah
# 11061                    Concordo, Cesinha! Falou tudo.

# %% [markdown]
# # 1. Who is most active in the group

# %%
print("Amount of messages sent by user")

df.groupby('user')['message'].count().sort_values(ascending=False).head(10)
# Out:
# Amount of messages sent by user
# user
# Victor Scagion    11062
# Name: message, dtype: int64

# %%
print("Número de mensagens mandadas")
df.groupby('user')['message'].count().sort_values(ascending=False).head(10)
# Out:
# Número de mensagens mandadas
# user
# Victor Scagion    11062
# Name: message, dtype: int64

# %% [markdown]
# # 2. Frequently used emojis in the group

# %%
# Count all the emojis in the chat.
emoji_counter = Counter()
emojis_list = map(lambda x: ''.join(x.split()), emoji.UNICODE_EMOJI.keys())
r = re.compile('|'.join(re.escape(p) for p in emojis_list))
for index, row in df.iterrows():
    emojis_found = r.findall(row['message'])
    for emoji_f in emojis_found:
        emoji_counter[emoji_f] +=1

for item in emoji_counter.most_common(10):
     print(f'{item[0]} - {item[1]}')
# Out:
# en - 4714
# es - 4670
# it - 1547
# pt - 27

# %%
r
# Out:
# re.compile(r'en|es|pt|it', re.UNICODE)

# %% [markdown]
# # 3. Sleep Cycles of the group

# %%
#3 sleep cycle 
df['hour'] = df['date'].apply(lambda x: x.hour)
df = df[['date', 'hour', 'user', 'message']]
df.groupby(['hour']).size().sort_index().plot(x="hour", kind='bar', figsize=(22,8))
plt.title('Nossas conversas distribuídas pelas 24hrs do dia', fontsize=30, color='#1F77B4')
# Out:
# Text(0.5, 1.0, 'Nossas conversas distribuídas pelas 24hrs do dia')

# %%
df
# Out:
#                      date  ...                                            message
# 0     2021-01-15 23:27:00  ...                              Eita, mais tagarelas
# 1     2021-01-15 23:29:00  ...                     roi, ou melhor, a paz de Deus
# 2     2021-01-15 23:30:00  ...                                           IRAAAAA
# 3     2021-01-15 23:30:00  ...                                              Amém
# 4     2021-01-15 23:30:00  ...                                          Hsushshs
# ...                   ...  ...                                                ...
# 11032 2021-03-28 01:00:00  ...                                      Hahahahahaha
# 11033 2021-03-28 01:11:00  ...  Aos cursos que são mais voltados para humanas ...
# 11034 2021-03-28 01:13:00  ...  Ademais todas as ciências são oriundas da filo...
# 11035 2021-03-28 01:13:00  ...  Pena que o irmão Gabriel de filo não ta aqui hah
# 11036 2021-03-28 01:26:00  ...                    Concordo, Cesinha! Falou tudo.
#
# [11037 rows x 4 columns]

# %%
df.loc[:'2020-01-08'].groupby(df['hour']).size().sort_index().plot(kind='bar', figsize=(22, 8))

# %% [markdown]
# # 4. Word Cloud

# %%
all_words = ' '
stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os", "a", "o", "rs", 'que','bem','vc','ai','ele','ela','eu','ma','pra',
                 'pq','vai','um','ja','tem','isso','mas', 'ta', 'se','la','sim','uma','nao','não','n','tbm','para','sei','agora',
                 'mesmo','aqui','esse','faz','tudo','minha','bom','entao','só','vo','vou','fazer','sou','acho','ainda','nossa',
                 'por','mais','como','seu','ser','deu','dou','mto','nem', 'ok', 'na', 'hj', 'eles', 'qual', 'são', 'pelo', 'Ah',
                  'aq', 'ou', 'aí', 'até', 'né', 'oq', 'era', 'dele', 'fui', 'sem', 'ei', 'fez', 'viu', 'estou', 'quero', 'ver',
                  'vou', 'tenho', 'foi', 'ne', 'entao', 'então', 'assim', 'já', 'Gente', 'essa', 'tá', 'ta', 'muito'])
all_summary = " ".join(word for word in df['message'].values)

wordcloud = WordCloud(width = 1000, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(all_summary) 


fig, ax = plt.subplots(figsize=(12,17))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
 
plt.imshow(wordcloud);
